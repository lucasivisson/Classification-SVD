# %%
## Trabalho Final de Classificação: SVD da Disciplina de Algebra Linear

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image
import glob
import numba
from sklearn.model_selection import train_test_split as division

# %%
### Redimensionando o tamanho das imagens de 400x400 para 40x40

# %%
images = glob.glob('*/*/*.png')

for file in images:
    img = Image.open(file)
    width, height = img.size
    (new_width, new_height) = (40, 40)
    img = img.resize(
        (round(new_width),
        round(new_height)),
        Image.ANTIALIAS)
    img.save(file, format='png')

# %%
### Dividindo as imagens em treino e teste (80% treino e 20% teste) e compondo nossa matriz de dados de treino com os dados das imagens de treino

# %%
for file in images:
    img = Image.open(file).convert('L')
    img.save(file, format='png')

images_array = np.asarray(glob.glob('*/*/*.png'))
teste = Image.open(images_array[0])
teste = np.asarray(teste, dtype=np.float32)/255

plt.figure(figsize=(4, 4))
im = plt.imshow(teste, aspect='auto', cmap='gray')
plt.axis("off")
plt.show()
print("tamanho da dimensão da imagem retirando o RGB:", teste.shape)
# Out:
# tamanho da dimensão da imagem retirando o RGB: (40, 40)

# %%
### Dividindo as imagens em treino e teste (80% treino e 20% teste) e compondo nossa matriz de dados de treino com os dados das imagens de treino

# %%
images_array = np.asarray(glob.glob('*/*/*.png'))
x_train, x_test = division(images_array, test_size=0.2, random_state=5)
images_train, images_test = division(x_test, test_size=0.2, random_state=5)
data_matrix = Image.open(images_train[0])
data_matrix = np.asarray(data_matrix, dtype=np.float32)/255
data_matrix = np.reshape(data_matrix, (1, 1600))

for i in range(1, images_train.shape[0]):
        aux = Image.open(images_train[i])
        aux = np.asarray(aux, dtype=np.float32)/255
        aux = np.reshape(aux, (1, 1600))
        data_matrix = np.vstack((data_matrix, aux))

print("dimensão da matriz de dados de treino:", data_matrix.shape)
plt.figure(figsize=(4, 4))
im = plt.imshow(data_matrix, aspect='auto', cmap='gray')
plt.axis("off")
plt.show()
# Out:
# dimensão da matriz de dados de treino: (6400, 1600)

# %%
### Centralizando a matriz de dados original data_matrix^ obtendo a matriz data_matrix centralizada.

# %%
centralized_data_matrix = data_matrix - np.mean(data_matrix, axis=0)
print(centralized_data_matrix.shape)
# Out:
# (6400, 1600)

# %%
### Compondo a matriz de dados de teste

# %%
test_data_matrix = Image.open(images_test[0])
test_data_matrix = np.asarray(test_data_matrix, dtype=np.float32)/255
test_data_matrix = np.reshape(test_data_matrix, (1, 1600))

for i in range(1, images_test.shape[0]):
        aux = Image.open(images_test[i])
        aux = np.asarray(aux, dtype=np.float32)/255
        aux = np.reshape(aux, (1, 1600))
        test_data_matrix = np.vstack((test_data_matrix, aux))

print("dimensão da matriz de dados de treino:", test_data_matrix.shape)
plt.figure(figsize=(4, 4))
im = plt.imshow(test_data_matrix, aspect='auto', cmap='gray')
plt.axis("off")
plt.show()
# Out:
# dimensão da matriz de dados de treino: (1600, 1600)

# %%
centralized_test_data_matrix = test_data_matrix - np.mean(test_data_matrix, axis=0)
print(centralized_test_data_matrix.shape)
# Out:
# (1600, 1600)

# %%
### Tarefas

# %%
### Calcular, para o respectivo banco de dados, a SVD da matriz de dados centralizados X. Gerar um gráfico de número de valores singulares versus variabilidade acumulada.

# %%
u, s, vt = np.linalg.svd(centralized_data_matrix, full_matrices=False)
print(u.shape)
print(s.shape)
print(vt.shape)
# Out:
# (6400, 1600)
# (1600,)
# (1600, 1600)

# %%
### Gerando a imagem das 20 primeiras eigenlegos

# %%
fig = plt.figure(figsize=(10,5))
for i in range(20):
    sub = fig.add_subplot(5, 4,i+1)
    sub.imshow(np.reshape(vt.T[:,i], (40,40)), cmap='gray')
    sub.set_xticks([])
    sub.set_yticks([])
    sub.set_xticklabels([])
    sub.set_yticklabels([])

# %%
### Gerando o a porcentagem de número de valores singulares versus variabilidade acumulada.

# %%
singular_vectors = np.array([0])
accumulated_variability = np.array([0])

for i in range(0, s.shape[0]-1, 10):
    aux = 100*((np.sum(s[0:i]**2))/(np.sum(s**2)))
    accumulated_variability = np.hstack((accumulated_variability, aux))

    singular_vectors = np.hstack((singular_vectors, i))

    print(f'Vetores singulares: {i}, Variabilidade acumulada: {aux}%')
# Out:
# Vetores singulares: 0, Variabilidade acumulada: 0.0%
# Vetores singulares: 10, Variabilidade acumulada: 65.23681879043579%
# Vetores singulares: 20, Variabilidade acumulada: 75.05866289138794%
# Vetores singulares: 30, Variabilidade acumulada: 80.07746934890747%
# Vetores singulares: 40, Variabilidade acumulada: 83.26314687728882%
# Vetores singulares: 50, Variabilidade acumulada: 85.55968403816223%
# Vetores singulares: 60, Variabilidade acumulada: 87.3844563961029%
# Vetores singulares: 70, Variabilidade acumulada: 88.75787854194641%
# Vetores singulares: 80, Variabilidade acumulada: 89.87345695495605%
# Vetores singulares: 90, Variabilidade acumulada: 90.80297350883484%
# Vetores singulares: 100, Variabilidade acumulada: 91.58589243888855%
# Vetores singulares: 110, Variabilidade acumulada: 92.26376414299011%
# Vetores singulares: 120, Variabilidade acumulada: 92.85373091697693%
# Vetores singulares: 130, Variabilidade acumulada: 93.37567090988159%
# Vetores singulares: 140, Variabilidade acumulada: 93.84602904319763%
# Vetores singulares: 150, Variabilidade acumulada: 94.27042007446289%
# Vetores singulares: 160, Variabilidade acumulada: 94.65628266334534%
# Vetores singulares: 170, Variabilidade acumulada: 95.00296711921692%
# Vetores singulares: 180, Variabilidade acumulada: 95.31733393669128%
# Vetores singulares: 190, Variabilidade acumulada: 95.60641646385193%
# Vetores singulares: 200, Variabilidade acumulada: 95.87400555610657%
# Vetores singulares: 210, Variabilidade acumulada: 96.11835479736328%
# Vetores singulares: 220, Variabilidade acumulada: 96.3435173034668%
# Vetores singulares: 230, Variabilidade acumulada: 96.55311107635498%
# Vetores singulares: 240, Variabilidade acumulada: 96.74721956253052%
# Vetores singulares: 250, Variabilidade acumulada: 96.92686796188354%
# Vetores singulares: 260, Variabilidade acumulada: 97.09472060203552%
# Vetores singulares: 270, Variabilidade acumulada: 97.25244641304016%
# Vetores singulares: 280, Variabilidade acumulada: 97.39994406700134%
# Vetores singulares: 290, Variabilidade acumulada: 97.53803014755249%
# Vetores singulares: 300, Variabilidade acumulada: 97.66746759414673%
# Vetores singulares: 310, Variabilidade acumulada: 97.78942465782166%
# Vetores singulares: 320, Variabilidade acumulada: 97.90418744087219%
# Vetores singulares: 330, Variabilidade acumulada: 98.0121910572052%
# Vetores singulares: 340, Variabilidade acumulada: 98.11441898345947%
# Vetores singulares: 350, Variabilidade acumulada: 98.21100234985352%
# Vetores singulares: 360, Variabilidade acumulada: 98.30268621444702%
# Vetores singulares: 370, Variabilidade acumulada: 98.38939309120178%
# Vetores singulares: 380, Variabilidade acumulada: 98.47116470336914%
# Vetores singulares: 390, Variabilidade acumulada: 98.54838252067566%
# Vetores singulares: 400, Variabilidade acumulada: 98.62139821052551%
# Vetores singulares: 410, Variabilidade acumulada: 98.69084358215332%
# Vetores singulares: 420, Variabilidade acumulada: 98.75699281692505%
# Vetores singulares: 430, Variabilidade acumulada: 98.81964325904846%
# Vetores singulares: 440, Variabilidade acumulada: 98.87892007827759%
# Vetores singulares: 450, Variabilidade acumulada: 98.93526434898376%
# Vetores singulares: 460, Variabilidade acumulada: 98.98883104324341%
# Vetores singulares: 470, Variabilidade acumulada: 99.03998970985413%
# Vetores singulares: 480, Variabilidade acumulada: 99.08859729766846%
# Vetores singulares: 490, Variabilidade acumulada: 99.13503527641296%
# Vetores singulares: 500, Variabilidade acumulada: 99.17912483215332%
# Vetores singulares: 510, Variabilidade acumulada: 99.22130703926086%
# Vetores singulares: 520, Variabilidade acumulada: 99.2616593837738%
# Vetores singulares: 530, Variabilidade acumulada: 99.30009245872498%
# Vetores singulares: 540, Variabilidade acumulada: 99.33668375015259%
# Vetores singulares: 550, Variabilidade acumulada: 99.37156438827515%
# Vetores singulares: 560, Variabilidade acumulada: 99.40493702888489%
# Vetores singulares: 570, Variabilidade acumulada: 99.43680167198181%
# Vetores singulares: 580, Variabilidade acumulada: 99.46708679199219%
# Vetores singulares: 590, Variabilidade acumulada: 99.495929479599%
# Vetores singulares: 600, Variabilidade acumulada: 99.52341318130493%
# Vetores singulares: 610, Variabilidade acumulada: 99.54963326454163%
# Vetores singulares: 620, Variabilidade acumulada: 99.57456588745117%
# Vetores singulares: 630, Variabilidade acumulada: 99.59818720817566%
# Vetores singulares: 640, Variabilidade acumulada: 99.62078928947449%
# Vetores singulares: 650, Variabilidade acumulada: 99.64225888252258%
# Vetores singulares: 660, Variabilidade acumulada: 99.66267347335815%
# Vetores singulares: 670, Variabilidade acumulada: 99.68212246894836%
# Vetores singulares: 680, Variabilidade acumulada: 99.70067143440247%
# Vetores singulares: 690, Variabilidade acumulada: 99.71832036972046%
# Vetores singulares: 700, Variabilidade acumulada: 99.73510503768921%
# Vetores singulares: 710, Variabilidade acumulada: 99.75101351737976%
# Vetores singulares: 720, Variabilidade acumulada: 99.76617693901062%
# Vetores singulares: 730, Variabilidade acumulada: 99.78054761886597%
# Vetores singulares: 740, Variabilidade acumulada: 99.7942328453064%
# Vetores singulares: 750, Variabilidade acumulada: 99.80719089508057%
# Vetores singulares: 760, Variabilidade acumulada: 99.81948137283325%
# Vetores singulares: 770, Variabilidade acumulada: 99.8311698436737%
# Vetores singulares: 780, Variabilidade acumulada: 99.84225034713745%
# Vetores singulares: 790, Variabilidade acumulada: 99.85283017158508%
# Vetores singulares: 800, Variabilidade acumulada: 99.86279606819153%
# Vetores singulares: 810, Variabilidade acumulada: 99.87223744392395%
# Vetores singulares: 820, Variabilidade acumulada: 99.88123774528503%
# Vetores singulares: 830, Variabilidade acumulada: 99.8897135257721%
# Vetores singulares: 840, Variabilidade acumulada: 99.89774823188782%
# Vetores singulares: 850, Variabilidade acumulada: 99.90532398223877%
# Vetores singulares: 860, Variabilidade acumulada: 99.91246461868286%
# Vetores singulares: 870, Variabilidade acumulada: 99.91918206214905%
# Vetores singulares: 880, Variabilidade acumulada: 99.92551803588867%
# Vetores singulares: 890, Variabilidade acumulada: 99.93147253990173%
# Vetores singulares: 900, Variabilidade acumulada: 99.93703365325928%
# Vetores singulares: 910, Variabilidade acumulada: 99.94224309921265%
# Vetores singulares: 920, Variabilidade acumulada: 99.9471366405487%
# Vetores singulares: 930, Variabilidade acumulada: 99.95168447494507%
# Vetores singulares: 940, Variabilidade acumulada: 99.9559223651886%
# Vetores singulares: 950, Variabilidade acumulada: 99.95985627174377%
# Vetores singulares: 960, Variabilidade acumulada: 99.9635100364685%
# Vetores singulares: 970, Variabilidade acumulada: 99.96691346168518%
# Vetores singulares: 980, Variabilidade acumulada: 99.97009634971619%
# Vetores singulares: 990, Variabilidade acumulada: 99.97303485870361%
# Vetores singulares: 1000, Variabilidade acumulada: 99.97575283050537%
# Vetores singulares: 1010, Variabilidade acumulada: 99.97825622558594%
# Vetores singulares: 1020, Variabilidade acumulada: 99.98056888580322%
# Vetores singulares: 1030, Variabilidade acumulada: 99.98268485069275%
# Vetores singulares: 1040, Variabilidade acumulada: 99.9846339225769%
# Vetores singulares: 1050, Variabilidade acumulada: 99.98640418052673%
# Vetores singulares: 1060, Variabilidade acumulada: 99.98800754547119%
# Vetores singulares: 1070, Variabilidade acumulada: 99.98949766159058%
# Vetores singulares: 1080, Variabilidade acumulada: 99.9908447265625%
# Vetores singulares: 1090, Variabilidade acumulada: 99.99205470085144%
# Vetores singulares: 1100, Variabilidade acumulada: 99.99314546585083%
# Vetores singulares: 1110, Variabilidade acumulada: 99.99411106109619%
# Vetores singulares: 1120, Variabilidade acumulada: 99.99499917030334%
# Vetores singulares: 1130, Variabilidade acumulada: 99.99576807022095%
# Vetores singulares: 1140, Variabilidade acumulada: 99.99644756317139%
# Vetores singulares: 1150, Variabilidade acumulada: 99.99704957008362%
# Vetores singulares: 1160, Variabilidade acumulada: 99.99755024909973%
# Vetores singulares: 1170, Variabilidade acumulada: 99.99800324440002%
# Vetores singulares: 1180, Variabilidade acumulada: 99.99838471412659%
# Vetores singulares: 1190, Variabilidade acumulada: 99.9987244606018%
# Vetores singulares: 1200, Variabilidade acumulada: 99.99901056289673%
# Vetores singulares: 1210, Variabilidade acumulada: 99.99924898147583%
# Vetores singulares: 1220, Variabilidade acumulada: 99.99943971633911%
# Vetores singulares: 1230, Variabilidade acumulada: 99.99958872795105%
# Vetores singulares: 1240, Variabilidade acumulada: 99.99971389770508%
# Vetores singulares: 1250, Variabilidade acumulada: 99.99978542327881%
# Vetores singulares: 1260, Variabilidade acumulada: 99.99986290931702%
# Vetores singulares: 1270, Variabilidade acumulada: 99.99991655349731%
# Vetores singulares: 1280, Variabilidade acumulada: 99.99995827674866%
# Vetores singulares: 1290, Variabilidade acumulada: 99.99997615814209%
# Vetores singulares: 1300, Variabilidade acumulada: 100.0%
# Vetores singulares: 1310, Variabilidade acumulada: 100.0%
# Vetores singulares: 1320, Variabilidade acumulada: 99.99998807907104%
# Vetores singulares: 1330, Variabilidade acumulada: 100.0%
# Vetores singulares: 1340, Variabilidade acumulada: 100.0%
# Vetores singulares: 1350, Variabilidade acumulada: 100.0%
# Vetores singulares: 1360, Variabilidade acumulada: 100.00001192092896%
# Vetores singulares: 1370, Variabilidade acumulada: 100.00001192092896%
# Vetores singulares: 1380, Variabilidade acumulada: 100.0%
# Vetores singulares: 1390, Variabilidade acumulada: 100.0%
# Vetores singulares: 1400, Variabilidade acumulada: 100.00001192092896%
# Vetores singulares: 1410, Variabilidade acumulada: 99.99998807907104%
# Vetores singulares: 1420, Variabilidade acumulada: 99.99998807907104%
# Vetores singulares: 1430, Variabilidade acumulada: 99.99998807907104%
# Vetores singulares: 1440, Variabilidade acumulada: 99.99998807907104%
# Vetores singulares: 1450, Variabilidade acumulada: 99.99998807907104%
# Vetores singulares: 1460, Variabilidade acumulada: 99.99998807907104%
# Vetores singulares: 1470, Variabilidade acumulada: 99.99998807907104%
# Vetores singulares: 1480, Variabilidade acumulada: 100.0%
# Vetores singulares: 1490, Variabilidade acumulada: 100.0%
# Vetores singulares: 1500, Variabilidade acumulada: 100.0%
# Vetores singulares: 1510, Variabilidade acumulada: 100.00001192092896%
# Vetores singulares: 1520, Variabilidade acumulada: 100.00001192092896%
# Vetores singulares: 1530, Variabilidade acumulada: 100.00001192092896%
# Vetores singulares: 1540, Variabilidade acumulada: 100.00001192092896%
# Vetores singulares: 1550, Variabilidade acumulada: 100.00001192092896%
# Vetores singulares: 1560, Variabilidade acumulada: 100.00001192092896%
# Vetores singulares: 1570, Variabilidade acumulada: 100.00001192092896%
# Vetores singulares: 1580, Variabilidade acumulada: 100.00001192092896%
# Vetores singulares: 1590, Variabilidade acumulada: 100.00002384185791%

# %%
### Gerando o gráfico de número de valores singulares versus variabilidade acumulada.

# %%
plt.figure(figsize=(5,5))
plt.plot(singular_vectors, accumulated_variability, lw=3.0)
plt.grid()
plt.ylabel("Variabilidade acumulada (%)")
plt.xlabel("Vetores singulares")
plt.axis([0, s.shape[0] + 10, 0, 100])
plt.show()

# %%
### Selecionar valores apropriados de variabilidade acumulada para reduzir a dimensionalidade do problema de classicação, resolvendo-o para o respectivo banco de dados.

# %%
r = 60
img_proj = vt.T[:,0:r]
projected_train_images = centralized_data_matrix@img_proj
projected_train_images.shape
# Out:
# (6400, 60)

# %%
r = 60
img_proj_test = vt.T[:,0:r]
projected_test_images = centralized_test_data_matrix@img_proj_test
projected_test_images.shape
# Out:
# (1600, 60)

# %%
#passa por todas as imagens de teste e ve o resultado encontrado
hits = 0
mistakes = 0
index= -1

@numba.jit(fastmath=True, cache=True, nopython=False)
def find_match(images_test, images_train, hits, mistakes):
    hits = 0
    mistakes = 0
    index= -1
    for i in range(1, images_test.shape[0]):
        test_image = np.reshape(np.asarray(Image.open(images_test[i]),dtype=np.float32)/255,(1, 1600))
        distancia = 50000000
        for j in range(1, images_train.shape[0]):
            dist = np.linalg.norm(projected_test_images[i,:]-projected_train_images[j,:])
            if dist <= distancia:
                index = j
                distancia = dist
            name = images_train[index]
        if images_test[i][16:20] == images_train[index][16:20]:
            hits+=1
        else:
            mistakes+=1
    total = hits+mistakes
    result = [hits, mistakes, total]
    return result

# %%
a = find_match(images_test, images_train, hits, mistakes);
a
# Out:
# <ipython-input-138-c4f4ea2d6b61>:6: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "find_match" failed type inference due to: Unknown attribute 'open' of type Module(<module 'PIL.Image' from '/usr/lib/python3/dist-packages/PIL/Image.py'>)
#
# File "<ipython-input-138-c4f4ea2d6b61>", line 12:
# def find_match(images_test, images_train, hits, mistakes):
#     <source elided>
#     for i in range(1, images_test.shape[0]):
#         test_image = np.reshape(np.asarray(Image.open(images_test[i]),dtype=np.float32)/255,(1, 1600))
#         ^
#
# During: typing of get attribute at <ipython-input-138-c4f4ea2d6b61> (12)
#
# File "<ipython-input-138-c4f4ea2d6b61>", line 12:
# def find_match(images_test, images_train, hits, mistakes):
#     <source elided>
#     for i in range(1, images_test.shape[0]):
#         test_image = np.reshape(np.asarray(Image.open(images_test[i]),dtype=np.float32)/255,(1, 1600))
#         ^
#
#   @numba.jit(fastmath=True, cache=True, nopython=False)
# <ipython-input-138-c4f4ea2d6b61>:6: NumbaWarning:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "find_match" failed type inference due to: Cannot determine Numba type of <class 'numba.core.dispatcher.LiftedLoop'>
#
# File "<ipython-input-138-c4f4ea2d6b61>", line 11:
# def find_match(images_test, images_train, hits, mistakes):
#     <source elided>
#     index= -1
#     for i in range(1, images_test.shape[0]):
#     ^
#
#   @numba.jit(fastmath=True, cache=True, nopython=False)
# /home/lucas/.local/lib/python3.8/site-packages/numba/core/object_mode_passes.py:151: NumbaWarning: Function "find_match" was compiled in object mode without forceobj=True, but has lifted loops.
#
# File "<ipython-input-138-c4f4ea2d6b61>", line 8:
# def find_match(images_test, images_train, hits, mistakes):
#     hits = 0
#     ^
#
#   warnings.warn(errors.NumbaWarning(warn_msg,
# /home/lucas/.local/lib/python3.8/site-packages/numba/core/object_mode_passes.py:161: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected, this is deprecated behaviour.
#
# For more information visit https://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "<ipython-input-138-c4f4ea2d6b61>", line 8:
# def find_match(images_test, images_train, hits, mistakes):
#     hits = 0
#     ^
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg,
# <ipython-input-138-c4f4ea2d6b61>:6: NumbaWarning: Cannot cache compiled function "find_match" as it uses lifted code
#   @numba.jit(fastmath=True, cache=True, nopython=False)
# <ipython-input-138-c4f4ea2d6b61>:6: NumbaWarning:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "find_match" failed type inference due to: Unknown attribute 'open' of type Module(<module 'PIL.Image' from '/usr/lib/python3/dist-packages/PIL/Image.py'>)
#
# File "<ipython-input-138-c4f4ea2d6b61>", line 12:
# def find_match(images_test, images_train, hits, mistakes):
#     <source elided>
#     for i in range(1, images_test.shape[0]):
#         test_image = np.reshape(np.asarray(Image.open(images_test[i]),dtype=np.float32)/255,(1, 1600))
#         ^
#
# During: typing of get attribute at <ipython-input-138-c4f4ea2d6b61> (12)
#
# File "<ipython-input-138-c4f4ea2d6b61>", line 12:
# def find_match(images_test, images_train, hits, mistakes):
#     <source elided>
#     for i in range(1, images_test.shape[0]):
#         test_image = np.reshape(np.asarray(Image.open(images_test[i]),dtype=np.float32)/255,(1, 1600))
#         ^
#
#   @numba.jit(fastmath=True, cache=True, nopython=False)
# /home/lucas/.local/lib/python3.8/site-packages/numba/core/object_mode_passes.py:151: NumbaWarning: Function "find_match" was compiled in object mode without forceobj=True.
#
# File "<ipython-input-138-c4f4ea2d6b61>", line 11:
# def find_match(images_test, images_train, hits, mistakes):
#     <source elided>
#     index= -1
#     for i in range(1, images_test.shape[0]):
#     ^
#
#   warnings.warn(errors.NumbaWarning(warn_msg,
# /home/lucas/.local/lib/python3.8/site-packages/numba/core/object_mode_passes.py:161: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected, this is deprecated behaviour.
#
# For more information visit https://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "<ipython-input-138-c4f4ea2d6b61>", line 11:
# def find_match(images_test, images_train, hits, mistakes):
#     <source elided>
#     index= -1
#     for i in range(1, images_test.shape[0]):
#     ^
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg,
# [778, 821, 1599]

# %%
print('acertos:', a[0])
print('erros:', a[1])
print('porcentagem:',100*(a[0]/a[2]))
# Out:
# acertos: 778
# erros: 821
# porcentagem: 48.65540963101939

# %%
images_test[1]
# Out:
# 'archive/dataset/3659 brick bow 1x4 361R.png'

# %%
images_train[653]
# Out:
# 'archive/dataset/3040 roof tile 1x2 057L.png'

# %%
#COLETOR DE DADOS PARA GERAR GRAFICOS
hit_vector = []
mistakes_vector = []
hit_rate_vector = []
accumulated_variability_vector = []

for z in range(1, 100, 10):
    r = z
    img_proj = vt.T[:,0:r]
    projected_train_images = centralized_data_matrix@img_proj

    img_proj_test = vt.T[:,0:r]
    projected_test_images = centralized_test_data_matrix@img_proj_test

    accuracy_result = find_match(images_test, images_train, hits, mistakes)
    hit_vector.append(accuracy_result[0])
    mistakes_vector.append(accuracy_result[1])
    hit_rate_vector.append(100*(accuracy_result[0]/accuracy_result[2]))
    accumulated_variability_vector.append(100*(np.sum(s[0:r]**2)/np.sum(s**2)))

for z in range(100,1000,200):
    r = z
    img_proj = vt.T[:,0:r]
    projected_train_images = centralized_data_matrix@img_proj

    img_proj_test = vt.T[:,0:r]
    projected_test_images = centralized_test_data_matrix@img_proj_test

    accuracy_result = find_match(images_test, images_train, hits, mistakes)
    hit_vector.append(accuracy_result[0])
    mistakes_vector.append(accuracy_result[1])
    hit_rate_vector.append(100*(accuracy_result[0]/accuracy_result[2]))
    accumulated_variability_vector.append(100*(np.sum(s[0:r]**2)/np.sum(s**2)))

for z in range(1000,vt.T.shape[1]-1,300):
    r = z
    img_proj = vt.T[:,0:r]
    projected_train_images = centralized_data_matrix@img_proj

    img_proj_test = vt.T[:,0:r]
    projected_test_images = centralized_test_data_matrix@img_proj_test

    accuracy_result = find_match(images_test, images_train, hits, mistakes)
    hit_vector.append(accuracy_result[0])
    mistakes_vector.append(accuracy_result[1])
    hit_rate_vector.append(100*(accuracy_result[0]/accuracy_result[2]))
    accumulated_variability_vector.append(100*(np.sum(s[0:r]**2)/np.sum(s**2)))

# %%
acertos = np.array(hit_vector)
erros = np.array(mistakes_vector)
taxaAcerto = np.array(hit_rate_vector)
variabilidadeAcumulada = np.array(accumulated_variability_vector)

plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(variabilidadeAcumulada,taxaAcerto,lw=3.0)
plt.grid()
plt.ylabel("Taxa de Acerto (%)")
plt.xlabel("Variabilidade Acumulada (%)")
plt.subplot(1,2,2)
plt.plot(taxaAcerto,acertos,lw=3.0)
plt.grid()
plt.ylabel("Acertos")
plt.xlabel("Taxa de Acerto (%)")
plt.show()
